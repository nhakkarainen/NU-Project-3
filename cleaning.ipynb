# %%
import pandas as pd

# %%
# import csvs
urldays = "Resources/DaysOnZillow_State.csv"
days_df = pd.read_csv(urldays)
days_df.head(2)
# Out:
#    Unnamed: 0  SizeRank  RegionID  RegionName RegionType  2010-01  2010-02  \
# 0           0       1.0         9  California      State    108.0    115.0
# 1           1       2.0        54       Texas      State    121.0    123.0
#
#    2010-03  2010-04  2010-05  ...  2019-05  2019-06  2019-07  2019-08  \
# 0    107.0    102.0     89.0  ...       56     57.0       60     62.0
# 1    122.0    111.0     98.0  ...       64     64.0       64     67.0
#
#    2019-09  2019-10  2019-11  2019-12  2020-01  2020-02
# 0       65     65.0     64.0     71.0       79     69.0
# 1       74     79.0     82.0     87.0       92     91.0
#
# [2 rows x 127 columns]

# %%
url1bed = "Resources/City_Zhvi_1bedroom.csv"
bed_1_df = pd.read_csv(url1bed)
bed_1_df.head(2)
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
#
#                             Metro          CountyName  1996-01-31  ...  \
# 0     New York-Newark-Jersey City       Queens County    139028.0  ...
# 1  Los Angeles-Long Beach-Anaheim  Los Angeles County    114152.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# 0    606162.0    604457.0    603126.0    601368.0    600138.0    598527.0
# 1    531014.0    530916.0    530814.0    531586.0    533161.0    534943.0
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31
# 0    597268.0    597019.0    596725.0    596432.0
# 1    537784.0    541161.0    546048.0    550710.0
#
# [2 rows x 300 columns]

# %%
url2bed = "Resources/City_Zhvi_2bedroom.csv"
bed_2_df = pd.read_csv(url2bed)
bed_2_df.head(2)
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
#
#                             Metro          CountyName  1996-01-31  ...  \
# 0     New York-Newark-Jersey City       Queens County    221378.0  ...
# 1  Los Angeles-Long Beach-Anaheim  Los Angeles County    160588.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# 0    758437.0    757140.0    755798.0    754176.0    752930.0    751581.0
# 1    630320.0    630983.0    632244.0    634144.0    637111.0    639818.0
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31
# 0    750470.0    749923.0    749112.0    748076.0
# 1    644225.0    649077.0    656189.0    663476.0
#
# [2 rows x 300 columns]

# %%
url3bed = "Resources/City_Zhvi_3bedroom.csv"
bed_3_df = pd.read_csv(url3bed)
bed_3_df.head(2)
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
#
#                             Metro          CountyName  1996-01-31  ...  \
# 0     New York-Newark-Jersey City       Queens County    206340.0  ...
# 1  Los Angeles-Long Beach-Anaheim  Los Angeles County    182221.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# 0    669867.0    669301.0    668754.0    667939.0    667235.0    666403.0
# 1    679709.0    680905.0    682903.0    685596.0    689404.0    692833.0
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31
# 0    665999.0    665829.0    665469.0    664884.0
# 1    698102.0    703865.0    712243.0    720780.0
#
# [2 rows x 300 columns]

# %%
# strip down to columns wanted
# for days on market dataset - dates Feb-2018 - Mar-2020
days_cols = ["RegionID", "RegionName", "2018-02", "2018-03", "2018-04", "2018-05", "2018-06",
            "2018-07", "2018-08", "2018-09", "2018-10", "2018-11", "2018-12",
            "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06",
            "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12",
            "2020-01", "2020-02"]
days_df_a = days_df[days_cols].copy()

days_df_a.head()
# Out:
#    RegionID  RegionName  2018-02  2018-03  2018-04  2018-05  2018-06  2018-07  \
# 0         9  California     62.0     50.0     50.0     50.0     52.0       55
# 1        54       Texas     82.0     64.0     59.0     57.0     60.0       61
# 2        43    New York    148.0    147.0    140.0    112.0    106.5      108
# 3        14     Florida     93.0     90.0     82.0     83.0     83.0       85
# 4        21    Illinois    126.0    109.0     77.0     77.0     78.0       79
#
#    2018-08  2018-09  ...  2019-05  2019-06  2019-07  2019-08  2019-09  \
# 0     56.0     60.0  ...       56     57.0       60     62.0       65
# 1     63.0     69.0  ...       64     64.0       64     67.0       74
# 2    112.0    118.0  ...      119    112.0      111    113.0      120
# 3     85.0     86.0  ...       88     87.0       86     84.0       86
# 4     80.0     85.0  ...       74     76.0       78     81.0       86
#
#    2019-10  2019-11  2019-12  2020-01  2020-02
# ...

# %%
# strip down to columns wanted
# for housing prices - dates Mar-2018 - Mar-2020
housing_cols = ["RegionID", "RegionName", "State", "CountyName", "2018-03-31", "2018-04-30", "2018-05-31", "2018-06-30",
            "2018-07-31", "2018-08-31", "2018-09-30", "2018-10-31", "2018-11-30", "2018-12-31",
            "2019-01-31", "2019-02-28", "2019-03-31", "2019-04-30", "2019-05-31", "2019-06-30",
            "2019-07-31", "2019-08-31", "2019-09-30", "2019-10-31", "2019-11-30", "2019-12-31",
            "2020-01-31", "2020-02-29", "2020-03-31"]
bed_1_df_a = bed_1_df[housing_cols].copy()
bed_2_df_a = bed_2_df[housing_cols].copy()
bed_3_df_a = bed_3_df[housing_cols].copy()

bed_1_df_a.head()
# Out:
#    RegionID   RegionName State          CountyName  2018-03-31  2018-04-30  \
# 0      6181     New York    NY       Queens County    611603.0    613536.0
# 1     12447  Los Angeles    CA  Los Angeles County    517180.0    522014.0
# 2     39051      Houston    TX       Harris County     99702.0    100296.0
# 3     17426      Chicago    IL         Cook County    240339.0    239624.0
# 4      6915  San Antonio    TX        Bexar County     81041.0     81949.0
#
#    2018-05-31  2018-06-30  2018-07-31  2018-08-31  ...  2019-06-30  \
# 0    614251.0    614393.0    614446.0    614655.0  ...    606162.0
# 1    524605.0    526132.0    528795.0    531680.0  ...    531014.0
# 2    100960.0    101299.0    101623.0    101855.0  ...    104937.0
# 3    239434.0    239531.0    239239.0    238904.0  ...    238850.0
# 4     82545.0     83022.0     83497.0     84360.0  ...     90717.0
#
#    2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# ...

# %%
# merge 1 bed and 2 bed data together
bed_1_2 = pd.merge(bed_1_df_a, bed_2_df_a, on=["RegionID", "RegionName", "State", "CountyName"], how="inner")
columns_2018 = {"2018-03-31_x": "2018-03-1bd", "2018-04-30_x": "2018-04-1bd",
                "2018-05-31_x": "2018-05-1bd", "2018-06-30_x": "2018-06-1bd", 
                "2018-07-31_x": "2018-07-1bd", "2018-08-31_x": "2018-08-1bd", 
                "2018-09-30_x": "2018-09-1bd", "2018-10-31_x": "2018-10-1bd", 
                "2018-11-30_x": "2018-11-1bd", "2018-12-31_x": "2018-12-1bd", 
                "2018-03-31_y": "2018-03-2bd", "2018-04-30_y": "2018-04-2bd",
                "2018-05-31_y": "2018-05-2bd", "2018-06-30_y": "2018-06-2bd", 
                "2018-07-31_y": "2018-07-2bd", "2018-08-31_y": "2018-08-2bd", 
                "2018-09-30_y": "2018-09-2bd", "2018-10-31_y": "2018-10-2bd", 
                "2018-11-30_y": "2018-11-2bd", "2018-12-31_y": "2018-12-2bd"
                }
bed_1_2.rename(columns=columns_2018, inplace=True)
columns_2019 = {"2019-01-31_x": "2019-01-1bd", "2019-02-28_x": "2019-02-1bd",
                "2019-03-31_x": "2019-03-1bd", "2019-04-30_x": "2019-04-1bd",
                "2019-05-31_x": "2019-05-1bd", "2019-06-30_x": "2019-06-1bd", 
                "2019-07-31_x": "2019-07-1bd", "2019-08-31_x": "2019-08-1bd", 
                "2019-09-30_x": "2019-09-1bd", "2019-10-31_x": "2019-10-1bd", 
                "2019-11-30_x": "2019-11-1bd", "2019-12-31_x": "2019-12-1bd",
                "2019-01-31_y": "2019-01-2bd", "2019-02-28_y": "2019-02-2bd",
                "2019-03-31_y": "2019-03-2bd", "2019-04-30_y": "2019-04-2bd",
                "2019-05-31_y": "2019-05-2bd", "2019-06-30_y": "2019-06-2bd", 
                "2019-07-31_y": "2019-07-2bd", "2019-08-31_y": "2019-08-2bd", 
                "2019-09-30_y": "2019-09-2bd", "2019-10-31_y": "2019-10-2bd", 
                "2019-11-30_y": "2019-11-2bd", "2019-12-31_y": "2019-12-2bd"
                }
bed_1_2.rename(columns=columns_2019, inplace=True)
columns_2020 = {"2020-01-31_x": "2020-01-1bd", "2020-02-29_x": "2020-02-1bd",
                "2020-03-31_x": "2020-03-1bd",
                "2020-01-31_y": "2020-01-2bd", "2020-02-29_y": "2020-02-2bd",
                "2020-03-31_y": "2020-03-2bd"
               }
bed_1_2.rename(columns=columns_2020, inplace=True)

bed_1_2.head(1)
# Out:
#    RegionID RegionName State     CountyName  2018-03-1bd  2018-04-1bd  \
# 0      6181   New York    NY  Queens County     611603.0     613536.0
#
#    2018-05-1bd  2018-06-1bd  2018-07-1bd  2018-08-1bd  ...  2019-06-2bd  \
# 0     614251.0     614393.0     614446.0     614655.0  ...     758437.0
#
#    2019-07-2bd  2019-08-2bd  2019-09-2bd  2019-10-2bd  2019-11-2bd  \
# 0     757140.0     755798.0     754176.0     752930.0     751581.0
#
#    2019-12-2bd  2020-01-2bd  2020-02-2bd  2020-03-2bd
# 0     750470.0     749923.0     749112.0     748076.0
#
# [1 rows x 54 columns]

# %%
# merge 3 bedroom data in
bed_1_2_3 = pd.merge(bed_1_2, bed_3_df_a, on=["RegionID", "RegionName", "State", "CountyName"], how="inner")
columns_3_2018 = {"2018-03-31": "2018-03-3bd", "2018-04-30": "2018-04-3bd",
                   "2018-05-31": "2018-05-3bd", "2018-06-30": "2018-06-3bd", 
                   "2018-07-31": "2018-07-3bd", "2018-08-31": "2018-08-3bd", 
                   "2018-09-30": "2018-09-3bd", "2018-10-31": "2018-10-3bd", 
                   "2018-11-30": "2018-11-3bd", "2018-12-31": "2018-12-3bd"
                  }
bed_1_2_3.rename(columns=columns_3_2018, inplace=True)

columns_3_2019 = {"2019-01-31": "2019-01-3bd", "2019-02-28": "2019-02-3bd",
                  "2019-03-31": "2019-03-3bd", "2019-04-30": "2019-04-3bd",
                  "2019-05-31": "2019-05-3bd", "2019-06-30": "2019-06-3bd", 
                  "2019-07-31": "2019-07-3bd", "2019-08-31": "2019-08-3bd", 
                  "2019-09-30": "2019-09-3bd", "2019-10-31": "2019-10-3bd", 
                  "2019-11-30": "2019-11-3bd", "2019-12-31": "2019-12-3bd",
                 }
bed_1_2_3.rename(columns=columns_3_2019, inplace=True)

columns_3_2020 = {"2020-01-31": "2020-01-3bd", "2020-02-29": "2020-02-3bd",
                  "2020-03-31": "2020-03-3bd"
                 }
bed_1_2_3.rename(columns=columns_3_2020, inplace=True)

bed_1_2_3
# Out:
#        RegionID        RegionName State          CountyName  2018-03-1bd  \
# 0          6181          New York    NY       Queens County     611603.0
# 1         12447       Los Angeles    CA  Los Angeles County     517180.0
# 2         39051           Houston    TX       Harris County      99702.0
# 3         17426           Chicago    IL         Cook County     240339.0
# 4          6915       San Antonio    TX        Bexar County      81041.0
# ...         ...               ...   ...                 ...          ...
# 14746     26389             Paris    ID    Bear Lake County     106969.0
# 14747     46631  Mount Charleston    NV        Clark County     246940.0
# 14748     36413        Washington    CA       Nevada County     258960.0
# 14749     47188    Poncha Springs    CO      Chaffee County     294633.0
# 14750     50522    Oriskany Falls    NY       Oneida County      82767.0
#
#        2018-04-1bd  2018-05-1bd  2018-06-1bd  2018-07-1bd  2018-08-1bd  ...  \
# ...

# %%
# double check to make sure got them all
list(bed_1_2_3.columns)
# Out:
# ['RegionID',
#  'RegionName',
#  'State',
#  'CountyName',
#  '2018-03-1bd',
#  '2018-04-1bd',
#  '2018-05-1bd',
#  '2018-06-1bd',
#  '2018-07-1bd',
#  '2018-08-1bd',
#  '2018-09-1bd',
#  '2018-10-1bd',
#  '2018-11-1bd',
#  '2018-12-1bd',
#  '2019-01-1bd',
#  '2019-02-1bd',
#  '2019-03-1bd',
#  '2019-04-1bd',
#  '2019-05-1bd',
#  '2019-06-1bd',
#  '2019-07-1bd',
#  '2019-08-1bd',
#  '2019-09-1bd',
#  '2019-10-1bd',
#  '2019-11-1bd',
#  '2019-12-1bd',
#  '2020-01-1bd',
#  '2020-02-1bd',
#  '2020-03-1bd',
#  '2018-03-2bd',
#  '2018-04-2bd',
#  '2018-05-2bd',
#  '2018-06-2bd',
#  '2018-07-2bd',
#  '2018-08-2bd',
#  '2018-09-2bd',
#  '2018-10-2bd',
#  '2018-11-2bd',
#  '2018-12-2bd',
#  '2019-01-2bd',
#  '2019-02-2bd',
#  '2019-03-2bd',
#  '2019-04-2bd',
#  '2019-05-2bd',
#  '2019-06-2bd',
#  '2019-07-2bd',
#  '2019-08-2bd',
#  '2019-09-2bd',
#  '2019-10-2bd',
#  '2019-11-2bd',
#  '2019-12-2bd',
#  '2020-01-2bd',
#  '2020-02-2bd',
#  '2020-03-2bd',
#  '2018-03-3bd',
#  '2018-04-3bd',
# ...

# %%
# double check to make sure no missing data
# still has 51 rows
bed_1_2_3.dropna(how='any', inplace=True)
# still has 52 rows 
days_df_a.dropna(how='any', inplace=True) 
bed_1_2_3
# Out:
#        RegionID        RegionName State          CountyName  2018-03-1bd  \
# 0          6181          New York    NY       Queens County     611603.0
# 1         12447       Los Angeles    CA  Los Angeles County     517180.0
# 2         39051           Houston    TX       Harris County      99702.0
# 3         17426           Chicago    IL         Cook County     240339.0
# 4          6915       San Antonio    TX        Bexar County      81041.0
# ...         ...               ...   ...                 ...          ...
# 14746     26389             Paris    ID    Bear Lake County     106969.0
# 14747     46631  Mount Charleston    NV        Clark County     246940.0
# 14748     36413        Washington    CA       Nevada County     258960.0
# 14749     47188    Poncha Springs    CO      Chaffee County     294633.0
# 14750     50522    Oriskany Falls    NY       Oneida County      82767.0
#
#        2018-04-1bd  2018-05-1bd  2018-06-1bd  2018-07-1bd  2018-08-1bd  ...  \
# ...

# %%
bed_1_2_3.to_csv("Output/housing_prices.csv", index=False)

# %%
days_df_a.to_csv("Output/days_on_market.csv", index=False)
