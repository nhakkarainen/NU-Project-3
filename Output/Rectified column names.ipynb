# %%
import pandas as pd
file_to_load = "days_on_market.csv"
market_data = pd.read_csv(file_to_load)
market_data
# Out:
#     RegionID            RegionName  2018-02  2018-03  2018-04  2018-05  \
# 0          9            California     62.0     50.0     50.0     50.0
# 1         54                 Texas     82.0     64.0     59.0     57.0
# 2         43              New York    148.0    147.0    140.0    112.0
# 3         14               Florida     93.0     90.0     82.0     83.0
# 4         21              Illinois    126.0    109.0     77.0     77.0
# 5         47          Pennsylvania    113.0    110.0     86.0     78.0
# 6         44                  Ohio     94.0     80.0     65.0     62.0
# 7         30              Michigan     96.0     89.0     68.0     61.0
# 8         16               Georgia     90.0     74.0     65.0     62.0
# 9         36        North Carolina     92.0     71.0     61.0     62.0
# 10        40            New Jersey    137.0    137.0    120.0    103.0
# 11        56              Virginia    100.0     73.0     61.0     61.0
# ...

# %%
market_df = market_data.rename(columns={'2018-02': 'Feb_2018', '2018-03': 'Mar_2018'})

# %%
market_df
# Out:
#     RegionID            RegionName  Feb_2018  Mar_2018  2018-04  2018-05  \
# 0          9            California      62.0      50.0     50.0     50.0
# 1         54                 Texas      82.0      64.0     59.0     57.0
# 2         43              New York     148.0     147.0    140.0    112.0
# 3         14               Florida      93.0      90.0     82.0     83.0
# 4         21              Illinois     126.0     109.0     77.0     77.0
# 5         47          Pennsylvania     113.0     110.0     86.0     78.0
# 6         44                  Ohio      94.0      80.0     65.0     62.0
# 7         30              Michigan      96.0      89.0     68.0     61.0
# 8         16               Georgia      90.0      74.0     65.0     62.0
# 9         36        North Carolina      92.0      71.0     61.0     62.0
# 10        40            New Jersey     137.0     137.0    120.0    103.0
# 11        56              Virginia     100.0      73.0     61.0     61.0
# ...

# %%
market_df = market_data.rename(columns={'2018-02': 'Feb_2018', '2018-03': 'Mar_2018','2018-04': 'Apr_2018', '2018-05': 'May_2018', '2018-06': 'Jun_2018', '2018-07': 'Jul_2018', '2018-08': 'Aug_2018', '2018-09': 'Sep_2018', 
                                        '2018-10': 'Oct_2018', '2018-11': 'Nov_2018', '2018-12': 'Dec_2018', '2019-01': 'Jan_2019', '2019-02': 'Feb_2019', '2019-03': 'Mar_2019', 
                                        '2019-04': 'Apr_2019', '2019-05': 'May_2019', '2019-06': 'Jun_2019', '2019-07': 'Jul_2019', '2019-08': 'Aug_2019', 
                                        '2019-09': 'Sep_2019', '2019-10': 'Oct_2019', '2019-11': 'Nov_2019', '2019-12': 'Dec_2019', '2020-01': 'Jan_2020', '2020-02': 'Feb_2020'})

# %%
market_df
# Out:
#     RegionID            RegionName  Feb_2018  Mar_2018  Apr_2018  May_2018  \
# 0          9            California      62.0      50.0      50.0      50.0
# 1         54                 Texas      82.0      64.0      59.0      57.0
# 2         43              New York     148.0     147.0     140.0     112.0
# 3         14               Florida      93.0      90.0      82.0      83.0
# 4         21              Illinois     126.0     109.0      77.0      77.0
# 5         47          Pennsylvania     113.0     110.0      86.0      78.0
# 6         44                  Ohio      94.0      80.0      65.0      62.0
# 7         30              Michigan      96.0      89.0      68.0      61.0
# 8         16               Georgia      90.0      74.0      65.0      62.0
# 9         36        North Carolina      92.0      71.0      61.0      62.0
# 10        40            New Jersey     137.0     137.0     120.0     103.0
# ...

# %%
market_df.to_csv(r'Output\Days_On_Market_Correct.csv', index = False)
